# %%
from data_types import Value, Network
from draw import draw_dot

# %%
a = Value(3)
b = Value(4)
c = a*b

# %%
d = Value(5)
e = d*c

# %%
xs = [
    [2, 4, 3],
    [3, -1, .4],
    [.6, 7, -4],
    [2, 9, -4]
]

ys = [1, -1, 0, 2]

n = Network(3, [4, 4, 1])
loss = n.train(xs, ys)

# %%
draw_dot(loss)

# %%
loss.backward()
draw_dot(loss)
