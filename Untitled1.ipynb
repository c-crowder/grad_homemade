# %%
from data_types import Value
from draw import draw_dot

# %%
a = Value(3)
b = Value(4)
c = a*b

# %%
d = Value(5)
e = d*c

# %%
draw_dot(e)

# %%
e.backward()

# %%
draw_dot(e)

# %%
f = a**2

# %%
draw_dot(f)

# %%
f.backward()

# %%
draw_dot(f)
